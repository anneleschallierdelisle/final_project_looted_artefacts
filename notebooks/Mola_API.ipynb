# %%
import requests
from collections import defaultdict, Counter
import time
import csv
import pandas as pd

BASE_URL = "https://mola.omeka.net/api/items"

# explore items content and element text parsed in order to choose the most appropriates

def fetch_items_page(page=1, per_page=50):
    params = {"page": page, "per_page": per_page}
    r = requests.get(BASE_URL, params=params, timeout=30)
    r.raise_for_status()
    return r.json()


def parse_element_texts(item):
    grouped = defaultdict(list)

    for entry in item.get("element_texts", []):
        field_name = entry.get("element", {}).get("name")
        text_value = entry.get("text")
        html_flag = entry.get("html", False)
        element_set = entry.get("element_set", {}).get("name")

        if not field_name:
            continue

        grouped[field_name].append({
            "text": text_value,
            "html": html_flag,
            "element_set": element_set
        })

    return dict(grouped)


def collect_all_keys(max_pages=None, sleep_seconds=0.2):
    page = 1
    field_counter = Counter()
    field_examples = defaultdict(list)
    parsed_items = []

    while True:
        items = fetch_items_page(page=page, per_page=50)

        if not items:
            break

        for item in items:
            parsed_fields = parse_element_texts(item)

            parsed_items.append({
                "item_id": item.get("id"),
                "url": item.get("url"),
                "fields": parsed_fields
            })

            for field_name, values in parsed_fields.items():
                field_counter[field_name] += 1

                # max 3 per field
                for v in values:
                    txt = v.get("text")
                    if txt and len(field_examples[field_name]) < 3:
                        if txt not in field_examples[field_name]:
                            field_examples[field_name].append(txt)

        print(f"Page {page} ran with ({len(items)} items)")
        page += 1

        if max_pages is not None and page > max_pages:
            break

        time.sleep(sleep_seconds)

    return parsed_items, field_counter, field_examples


if __name__ == "__main__":
    parsed_items, field_counter, field_examples = collect_all_keys(max_pages=5)

    print("\n--- Found fields ---")
    for field_name, count in field_counter.most_common():
        print(f"{field_name}: {count}")

    print("\n--- Content examples ---")
    for field_name, examples in field_examples.items():
        print(f"\n{field_name}")
        for ex in examples:
            print(f"  - {ex}")
# Out:
# Page 1 ran with (50 items)
# Page 2 ran with (50 items)
# Page 3 ran with (50 items)
# Page 4 ran with (27 items)
#
# --- Found fields ---
# Title: 177
# Object or Group Name: 172
# Number of Objects: 172
# Repatriated?: 172
# Year Returned: 172
# Case Summary: 172
# Sending Country: 172
# Receiving Country: 172
# Reason for Return: 172
# Sources: 172
# MOLA Contributor(s): 172
# Status: 172
# Object Materials: 171
# Country of Origin: 171
# Peer Reviewed By: 171
# Description of Object(s): 171
# Object Type: 170
# Returning Entity: 167
# Creation Date: 167
# Images: 167
# Culture: 166
# Size: 166
# Findspot: 151
# Date Looted: 150
# Current Location: 139
# Dealer: 119
# Year Acquired: 114
# Year of Last Price: 107
# Museum Name: 106
# Last Known Price, Valuation or Estimate: 106
# Value in 2024 US Dollars: 105
# Museum Donation or Purchase?: 104
# Criminal Behaviors Alleged: 98
# Research Notes: 97
# Alleged Looter: 91
# Alleged Smuggler: 91
# Law Enforcement Entity: 89
# Documents: 88
# Alternate Name(s): 86
# Private Collector: 83
# See Also: 83
# Expert Review: 83
# Image Captions: 77
# Museum Accession Number: 73
# Prosecuting Entity: 72
# Museum Curator: 69
# Gallery: 68
# Provenance Summary: 61
# Operation Name: 58
# False Provenance: 54
# Court Case and Number: 46
# Auction House: 36
# Auction Details: 33
# Facilitator: 27
# Transportation or Storage Company: 26
# Restoration/Conservation: 25
# Tags: 20
# Auction Realized Price: 19
# Subject: 1
#
# --- Content examples ---
#
# Title
#   - Triangular Support for a Candelabrum or Column with Reliefs
#   - 2 Canosan Volute Greek Kraters
#   - A Bronze Figure of Zeus
#
# Object or Group Name
#   - Triangular Support for a Candelabrum or Column with Reliefs
#   - 2 Canosan Volute Greek Kraters
#   - A Bronze Figure of Zeus
#
# Object Type
#   - Sculpture – statues, carvings, bronzes, reliefs, figurines
#   - Vessel – pots, amphorae, vases, kraters
#   - Vessel
#
# Number of Objects
#   - 1
#   - 2
#   - 16
#
# Object Materials
#   - Marble
#   - Ceramic
#   - Bronze
#
# Country of Origin
#   - Italy
#   - Iraq
#   - Greece
#
# Culture
#   - Roman
#   - Canosan Greek
#   - Late Hellenistic or Early Roman Imperial
#
# Dealer
#   - Giacomo Medici
#   - Robert Hecht
#   - Edward Merrin
#
# Private Collector
#   - Cornelius C. Vermeule, III
#   - Private Collection, New York
#   - Lawrence and Barbara Fleischman Collection, New York
#
# Museum Accession Number
#   - 1992.31
#   - 1977.92
#   - 135.2012.2
#
# Year Acquired
#   - 1992
#   - 1986
#   - 1977
#
# Museum Donation or Purchase?
#   - Donation
#   - Purchase
#   - Fractional gift
#
# Repatriated?
#   - Yes
#   - On indefinite loan
#
# Year Returned
#   - 2006
#   - 2012
#   - 2010
#
# Case Summary
#   - This triangular marble fragment of a column or candelabrum shaft featuring reliefs depicting Hermes, Dionysus and Artemis on each side, was restituted to Italy from the Museum of Fine Arts, Boston in 2006 after it was conclusively linked to Giacomo Medici’s antiquities trafficking ring.
#
# The column fragment formerly belonged to Cornelius C. Vermeule, III, the Museum of Fine Arts’ Curator of Classical Art. Vermeule loaned the piece to the MFA in 1980, and in 1992 he and his wife, Harvard professor and archaeologist Emily Vermeule, donated it to the museum. Vermeule had ties to several known antiquities traffickers, including  Giacomo Medici and Robert Hecht.
#
# In 2005, as part of its sweeping investigation of American antiquities collections, the Italian Ministry of Culture identified 13 works in the MFA’s collection —the candelabrum fragment, a large statue of Emperor Hadrian’s wife Sabina, and 11 Attic, Apulian, and Lucanian vessels— as looted artifacts.
#
# When the Ministry requested the items’ return, MFA deputy director Katherine Getchell initially said, “There’s absolutely nothing we’ve seen or heard that proves anything to us.”  In 2006, however, in the face of compelling evidence, including a photo showing the column fragment in a field soon after it was looted, the MFA agreed to repatriate all the disputed works. Three of these - the candelabrum, an Attic red-figure lekythos, and an Attic red-figure hydria - had been donated by Cornelius Vermeule.
#
# On September 28, 2006, the MFA repatriated the objects and signed an understanding with the Italian Ministry of Culture, agreeing to provide Italy with information concerning future acquisitions of Italian antiquities in exchange for loans and cultural collaborations.
#
#   - These kraters first surfaced on the market on May 30th, 1986 in Sotheby's Antiquities and Islamic Works of Art auction.
#
# Their provenience is believed to be somewhere in Apulia, Southern Italy. A 1995 raid on Italian antiquities trafficker Giacomo Medici's Geneva warehouse revealed Polaroids of the kraters prior to conservation. A 2001 raid on Robert Hecht's Paris flat revealed additional post-conservation Polaroids of the vases.
#
# Christos Tsirogiannis connected these images to the vases when they were offered for auction again at Christie's in 2012. The vases did not sell and were returned by Christie's to an unnamed New York seller. After Tsirogiannis alerted the Italian authorities, the vases were repatriated to Italy in September 2012. In 2013, they were exhibited along with other repatriated items at the National Museum of Castel Sant'Angelo in Rome.
#   - The bronze statue of Zeus was stolen in 1980 from the Museo Nazionale Romano in Rome. Despite its illicit origin, it reappeared in scholarly and curatorial circles within a few years.
#
# In 1984, a publication by Joyce Geary Volk listed the statue as being in the collection of antiquities dealer Edward H. Merrin. According to the publication, Merrin had acquired it from another dealer who claimed the piece came from a Swiss collector in the late 1960s.
#
# By 1988, the statue was exhibited at the Cleveland Museum of Art as the property of Mr. and Mrs. Lawrence A. Fleischman.
#
# In 2004, a photograph of the statue appeared in a Sotheby’s auction catalogue. This image allowed investigators to trace the object to its consignor, an unnamed gallery in New York.
#
# The bronze statue was recovered in 2010 thanks to the effort of the Carabinieri Tutela del Patrimonio Culturale (TPC)
#
# Sending Country
#   - USA
#   - Switzerland
#   - UK
#
# Returning Entity
#   - Museum of Fine Arts, Boston
#   - Christie's
#   - Sotheby's, on behalf on consignor
#
# Receiving Country
#   - Italy
#   - Iraq
#   - Greece
#
# Reason for Return
#   - Claim from country of origin
#   - Law Enforcement Seizure
#   - Court ordered civil forteiture
#
# Current Location
#   - Italy
#   - Italy. Most recently exhibited at the National Museum of Castel Sant’ Angelo in Rome, May 21st to November 5th, 2013.
#   - National Roman Museum
#
# Sources
#   - <p><em>Boston Museum Returns 13 Ancient Works to Italy<br /></em><a href="https://web.archive.org/web/20260125202903/https://www.nytimes.com/2006/09/29/arts/design/29mfa.html">https://web.archive.org/web/20260125202903/https://www.nytimes.com/2006/09/29/arts/design/29mfa.html</a></p>
#   - <p><em>MFA: Triangular Support for a Candelabrum Shaft<br /></em><a href="https://web.archive.org/web/20260125203621/https://collections.mfa.org/objects/150373">https://web.archive.org/web/20260125203621/https://collections.mfa.org/objects/150373</a></p>
#   - <p><em>MFA: Antiquities and Archaeological Material<br /></em><a href="https://web.archive.org/web/20260125204012/https://www.mfa.org/collections/provenance/antiquities-and-archeological-material">https://web.archive.org/web/20260125204012/https://www.mfa.org/collections/provenance/antiquities-and-archeological-material</a></p>
#
# MOLA Contributor(s)
#   - Emily Hamann
#   - Casey Bennett; Damien Huffer
#   - Casey Bennett
#
# Peer Reviewed By
#   - Vanessa Rousseau
# Ilaria Bortot
# Lisa Duffy-Zeballos
#   - Vanessa Rousseau; Damien Huffer
#   - Vanessa Rousseau
#
# Status
#   - Completed
#   - Ready for review
#   - In progress
#
# Creation Date
#   - 20 C.E. - 60 C.E.
#   - Early 3rd Century BCE
#   - 50 BCE - 100 CE
#
# Description of Object(s)
#   - Three-sided marble column fragment decorated on each panel with a relief showing three divinities walking to the left.
#
# The relief panels depict: Hermes with winged ankles, wearing a chlaina and a wreath; Dionysus in a long-sleeved tunic, holding a thyrsos and a drinking horn; and Artemis wearing a peplos and belted chiton and carrying a torch and a quiver on her back. The monument is damaged at the top, cutting off the goddess' head. (16 1/8 in.)
#   - A pair of Canosan volute kraters
#   - This 11/16 inches tall bronze statuette depicts Zeus standing in a contrapposto pose with his right arm raised—likely once holding a thunderbolt or scepter, now missing. The figure is finely modeled, with defined musculature and stylized curls in the hair and beard, characteristic of Roman bronze workmanship influenced by earlier Greek prototypes.
#
#
# Size
#   - 3
#   - 2
#   - 4
#
# Provenance Summary
#   - By 1980: In the possession of Cornelius C. Vermeule III, Cambridge, Massachusetts.
#
# 1992: Donated to the Museum of Fine Arts, Boston (MFA) by Cornelius C. Vermeule III and Emily T. Vermeule.
#
# 2005: Italian authorities formally request the return of the objects.
#
# September 21, 2006: The Hermes relief is deaccessioned by the MFA for transfer to the Republic of Italy.
#
# October 2006: The relief is repatriated to Italy, along with the other 12 disputed antiquities.
#
#
#   - Before 1980: Housed in the collection of the Museo Nazionale Romano, Rome, Italy.
#
# 1980: Stolen from the Museo Nazionale Romano, near Termini station in Rome.
#
# By 1984: Listed in a publication by Joyce Geary Volk as being in the collection of Edward H. Merrin, New York antiquities dealer.
#
# By 1988: Exhibited at the Cleveland Museum of Art, recorded as the property of Mr. and Mrs. Lawrence A. Fleischman.
#
# 2004: A photograph of the statue appeared in a Sotheby’s auction catalogue, helping authorities trace it to an unnamed New York gallery.
#
# Post-2006: Identified by Italian authorities as looted property.
#
# 2010: Recovered by the Carabinieri TPC
#   - Unknown: Giacomo Medici and Gianfranco Becchina acquire the donkey-shaped rhyton
#
# Unknown (late 1960s or early 1970s): Medici and Becchina sold the rhyton to antiquities dealer, Robert Hecht.
#
# 1977: Robert Hecht, under the auction house 'Summa Galleries', sells the rhyton to the Cleveland Museum of Art.
#
# January 1978: The rhyton is first mentioned in the Cleveland Museum of Art's Bulletin, 'The Year in Review for 1977', by the then Director of the Museum, Sherman E. Lee.
#
# 1995: The Italian Carabinieri Division for the Protection of Cultural Heritage (TPC) raid Medici's storeroom's in Geneva Freeport, recovering polaroids tracing the rhyton to Hecht and the Cleveland Museum of Art.
#
# May 2007: The Italian Ministry for Cultural Assets and Activities and the Cleveland Museum of Art begins negotiations to repatriate 14 artifacts they believe have been illicitly trafficked out of Italy.
#
# November 19 2008: The Cleveland Museum of Art agrees to repatriate the donkey-head rhyton along with 14 other artifacts.
#
#
# Museum Name
#   - Museum of Fine Arts, Boston
#   - Cleveland Museum of Art
#   - Dallas Museum of Art
#
# See Also
#   - <a href="https://mola.omeka.net/items/show/995">Sabina</a>
#   - <a href="https://mola.omeka.net/admin/items/show/id/954">1st Century A.D. Roman Female Marble Torso</a>
#   - <a href="https://mola.omeka.net/items/show/942">Onesimos Kylix</a>
#
# Image Captions
#   - A. A triangular column fragment showing relief of Dionysus on one side
# B. Photograph showing the column fragment soon after it was looted
#   - A headless stone statue of the Sumerian king Entemena of Lagash.
#   - A. Bronze Etruscan candelabrum showing a satyr and a cloaked companion atop a lotus shaped bloom, 112 cm h.
#
# Images
#   - <p><em>Museum of Fine Arts, Boston Collections<br /></em><a href="https://web.archive.org/save/https://collections.mfa.org/objects/150373">https://web.archive.org/save/https://collections.mfa.org/objects/150373</a><br /><br />Medici Polaroid, via Jason Felch</p>
#   - <a href="https://nordonart.files.wordpress.com/2012/06/screen-shot-2012-06-01-at-9-11-55-am.png" class="hoverZoomLink">https://nordonart.files.wordpress.com/2012/06/screen-shot-2012-06-01-at-9-11-55-am.png</a>
#   - <a href="https://web.archive.org/web/20140226171630/http://i.telegraph.co.uk/multimedia/archive/01766/Italy-Statues_1766859b.jpg" class="hoverZoomLink">https://web.archive.org/web/20140226171630/http://i.telegraph.co.uk/multimedia/archive/01766/Italy-Statues_1766859b.jpg</a>
#
# Findspot
#   - Apulia, Italy
#   - Unknown
#   - Apulia
#
# Expert Review
#   - Christos Tsirogiannis
#   - Mohsen Hassan
#   - John Malcolm Russell
#
# Auction House
#   - Sotheby's
#   -  Christie's New York
#   - Sotheby's
#
# Auction Realized Price
#   - Sotheby's USD $14,300
#   -  Christie's Not Sold
#   - 120,300 euros (165,000 dollars)
#
# Year of Last Price
#   - 2012
#   - 2004
#   - 1981
#
# Documents
#   - David W. J. Gill and Christos Tsirogiannis, "Polaroids from the Medici Dossier: Continued Sightings on the Market" The Journal of Art Crime (Spring 2011)
#   - <a href="https://www.documentcloud.org/documents/24172045-becchina-italian-court-file">https://www.documentcloud.org/documents/24172045-becchina-italian-court-file</a>
#   - <a href="https://www.documentcloud.org/documents/24240272-ice-response-entema-docs">https://www.documentcloud.org/documents/24240272-ice-response-entema-docs</a>
#
# Auction Details
#   - Sotheby's
# Auction date: 1986
# Auction lot number: lot 24
# Auction estimated value: USD $6,000 - 9,000
#   - Christie's
# Auction date: 2012
# Auction lot number: lot 99
# Auction estimated value: USD $40,000 - 60,000
#   - Auction date: 9/9/2004
#
# Last Known Price, Valuation or Estimate
#   - USD $14,300
#   - 120,300 euros (165,000 dollars)
#   - USD $275,000
#
# Research Notes
#   - Need to convert 2012 price to 2024 dollars
# 7/1/2025 Completed?
#   - Other sources: <a href="https://lootingmatters.blogspot.com/2013/05/two-canosan-kraters-returned-to-italy.html">https://lootingmatters.blogspot.com/2013/05/two-canosan-kraters-returned-to-italy.html</a>
#   - Other sources: <br /><a href="https://lootingmatters.blogspot.com/2010/11/bronze-zeus-returned-to-italy.html">https://lootingmatters.blogspot.com/2010/11/bronze-zeus-returned-to-italy.html</a><br /><a href="https://www.prnewswire.com/news-releases/looting-matters-zeus-returns-to-italy-110848314.html">https://www.prnewswire.com/news-releases/looting-matters-zeus-returns-to-italy-110848314.html</a>
#
# False Provenance
#   - From Christie's auction, June 8, 2012: 'Provenance: Private Collection, New York; Anonymous Sale; Sotheby’s, New York, 30 May 1986, lot 24.'
#   - Anonymous Swiss Collector in the late 1960s
#   - Switzerland
#
# Value in 2024 US Dollars
#   - 18,978
#
#   - 274010
#   - USD $921,816
#
# Criminal Behaviors Alleged
#   - Theft (stolen from a documented collection, rather than looted)
#   - Modern conflict looting
#   - Document falsification
#
# Date Looted
#   - 1980
#   - Unknown
#   - late 1970s
#
# Gallery
#   - Merrin Gallery
#   - Summa Gallery
#   - Antike Kunst Palladion
#
# Museum Curator
#   - John Cooney
#   - Jay Gates
#   - Jiří Frel
#
# Alleged Looter
#   - Unknown
#   - Antimo Caccipuoti
#   - Unknown
#
# Alleged Smuggler
#   - Unknown
#   - Pasquale Camera
#   - Giacomo Medici
#
# Law Enforcement Entity
#   - Italian Carabinieri Division for the Protection of Cultural Heritage (TPC)
#   - Federal Office of Switzerland Police
#   - Geneva Cantonal Office of Switzerland Police
#
# Operation Name
#   - Medici Investigation
#   - Becchina Investigation
#   - Medici Trafficking Network
#
# Alternate Name(s)
#   - Calyx Krater by the painter Asteas
#   - Paestan red-figure calyx krater, painted and signed by Asteas
#   - Entemena of Lagash
#
# Prosecuting Entity
#   - Italian state
#   - United States Attorney for the Central District of California
#   - Italy
#
# Facilitator
#   - Unknown
#   - Marion True
#   - Carlo Ciochetti
#
# Transportation or Storage Company
#   - Unknown
#   - Geneva Free Port
#   - Geneva Freeport
#
# Restoration/Conservation
#   - Fritz Burki & Son
#   - Fritz Bürki
#   - J. Paul Getty Museum (reassembled from fragments)
#
# Court Case and Number
#   - Italy v Marion True
#   - Italy vs Marion True
#   - U.S. v. One Ancient Roman Sarcophagus Lid with Sculpture of Reclining Woman
#
# Subject
#   - Attic black-figured hydria, attributed to the circle of the Antimenes painter
#
# Tags
#   - India
#   - Italy
#   - China

# %% [markdown]
# Based on both objectives (temporal trajectory map) and most complete text elements, we selected 17 fields.
# | Field                     | Count |
# |---------------------------|-------|
# | Title                     | 177   |
# | Repatriated?              | 172   |
# | Year Returned             | 172   |
# | Sending Country           | 172   |
# | Receiving Country         | 172   |
# | Object Materials          | 171   |
# | Country of Origin         | 171   |
# | Description of Object(s)  | 171   |
# | Object Type               | 170   |
# | Culture                   | 166   |
# | Size                      | 166   |
# | Findspot                  | 151   |
# | Date Looted               | 150   |
# | Current Location          | 139   |
# | Dealer                    | 119   |
# | Year Acquired             | 114   |
# | Museum Name               | 106   |

# %%
import pandas as pd
# Chosen fields for filtering text elements (name, text)
FIELDS = [
    "Title", "Repatriated?", "Year Returned", "Sending Country",
    "Receiving Country", "Object Materials", "Country of Origin",
    "Description of Object(s)", "Object Type", "Culture", "Size",
    "Findspot", "Date Looted", "Current Location", "Dealer",
    "Year Acquired", "Museum Name"
]

def parse_item(item):
    data = defaultdict(list) #allows to store several values

    for entry in item.get("element_texts", []): #browse all text elements and get key:value
        name = entry.get("element", {}).get("name")
        text = entry.get("text")

        if name in FIELDS and text:
            data[name].append(text)

    # string if one value otherwise join)
    result = {}
    for f in FIELDS:
        vals = data.get(f)
        if not vals:
            result[f] = None
        elif len(vals) == 1:
            result[f] = vals[0]
        else:
            result[f] = " | ".join(vals)

    return result


def fetch_all():
    page = 1
    rows = []

    while True:
        r = requests.get(BASE_URL, params={"page": page, "per_page": 50}, timeout=30)
        items = r.json()

        if not items:
            break

        for item in items:
            parsed = parse_item(item)
            parsed["id"] = item["id"]
            rows.append(parsed)

        print(f"page {page}")
        page += 1
        time.sleep(0.2)

    return rows


rows = fetch_all()

# CSV export
with open("../data/raw/mola_extraction.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["id"] + FIELDS)
    writer.writeheader()
    writer.writerows(rows)
# Out:
# page 1
# page 2
# page 3
# page 4

# %%
df_mola =  pd.DataFrame(rows)
#df_mola.head(5)

# %%
summary = pd.DataFrame({
    "unique_values": df_mola.nunique(dropna=False),
    "missing_values": df_mola.isna().sum()}).sort_values(by = "unique_values", ascending=True)
#print(summary) -> many content apper like lists with | however are str

# %%
# check if these two fields have the same values (and they have)
((df_mola["Receiving Country"] == df_mola["Country of Origin"]) & df_mola["Receiving Country"].notna()).sum()
# Out:
# np.int64(161)

# %%
# explore unique values for each categorical column
cols = ["Repatriated?", "Size", "Sending Country", "Country of Origin","Receiving Country", "Year Returned", "Object Type",
"Object Materials", "Museum Name", "Year Acquired", "Date Looted"]

#for col in cols:
    #print(f"\n{col}")
    #print(df_mola[col].dropna().unique())

# many different unique values, appaearing as lists while strings.

# %%
# additional filtering and extraction of the first word - arbitrary choice
df_mola_final = df_mola.copy()
final_cols = ["Sending Country", "Receiving Country", "Year Returned", "Object Type",
"Object Materials", "Year Acquired", "Date Looted"]
for col in final_cols:
    df_mola_final[col] = df_mola_final[col].str.split("|").str[0].str.strip()
    print(f"\n{col}")
    print(df_mola_final[col].dropna().unique())
# Out:
# Sending Country
# ['USA' 'Switzerland' 'UK' 'Germany' 'Australia' 'Canada' 'China' 'France'
#  'Greece' 'Italy' 'Sweden' 'Belgium' 'Argentina' 'Netherlands' 'Thailand']
#
# Receiving Country
# ['Italy' 'Iraq' 'Greece' 'Türkiye' 'Albania' 'Romania' 'Thailand' 'Iran'
#  'Nigeria' 'Costa Rica' 'India' 'Cambodia' 'Pakistan' 'USA' 'Cyprus'
#  'Yemen' 'Peru' 'Guatemala' 'Mexico' 'Lebanon' 'Libya' 'Hungary' 'Syria'
#  'Armenia' 'China' 'Afghanistan' 'Ethiopia' 'Canada' 'Egypt' 'Nepal'
#  'Vietnam' 'Ghana' 'UK' 'Saudi Arabia' 'Spain' 'Haiti' 'Sri Lanka']
#
# Year Returned
# ['2006' '2012' '2010' '2008' '2005' '2007' '1999' '2011' '1996' '2014'
#  '1952' '2000' '2013' '1988' '2020' '2016' '2015' '1992' '1976' '2001'
#  '1991' '2004' '2022' '2021' '2023' '2017; 2021; 2022; 2025; 2026' '2002'
#  '2018' '2017' '1982' '2009' '2003' '2024' '2019' '1993'
#  'Between 1980 and 2019' '2016 (MHA Nation, North Dakota, United States)'
#  '2006 (273 objects retuned to Peru)' 'Various' '1986' '1998' '2025']
#
# Object Type
# ['Sculpture – statues, carvings, bronzes, reliefs, figurines'
#  'Vessel – pots, amphorae, vases, kraters' 'Vessel' 'Sculpture'
#  'Lighting Device – lamps, candelabrum, lanterns' 'Various'
#  'Funerary Object – coffins, mummy portraits, grave goods'
#  'Currency – coins, weights, exchange goods'
#  'Jewelry – bracelets, rings, personal decoration'
#  'Religious Work – crucifixes, shrine objects, icons, religious texts'
#  'Architecture – antefixes, doors, sconces, friezes'
#  'Information Artifact' 'Visual Work'
#  'Information Artifact – books, seals, plaques, scrolls'
#  'Monument – obelisks, stelae, tombstones, totem poles'
#  'Visual Work – paintings, frescos, mosaics' 'Tablet' 'Currency'
#  'Fragment' 'Architectural Element' 'Ornament' 'Obelisk'
#  'Textile – fabrics, clothing, fiber-based objects' 'Human Remains'
#  'Human Remains – skeletons, mummies' 'Funerary Object'
#  'Equipment – weapons, helmets, tools, musical instruments']
#
# Object Materials
# ['Marble' 'Ceramic' 'Bronze' 'Stone' 'Terracotta' 'Silver' 'Gold'
#  'Various' 'Chlorite' 'Sandstone' 'Clay' 'Lead' 'Wood' 'Limestone'
#  'Basalt' 'Other' 'Textile' 'Human Remains' 'Copper' 'Brass' 'Granite'
#  'Alabaster' 'Lime Plaster' 'Gold Leaf']
#
# Year Acquired
# ['1992' '1986' '1977' '1996' '1981' '1985\r\n1988\r\n1996' '1990' '1983'
#  '1985' '1972' '1981 and 1982 (seperate transactions)' '1993' '1984'
#  '1948' '1982' '1966' '1967' '2002-2005' '1991' '1979' '2014' '1932'
#  '2016' '1999' '2000' '1987 - 1992, in fragments' '1973' 'not acquired'
#  '1994 or earlier' '2006' '1911-1916' '1988' '1976' '1950 or 1951' '1968'
#  '2010' '2007' 'Head: 2003 \r\nLeg: 1968' '2008' '1975' '1937' '1935'
#  '1929' '1980' '2007 (pledged)' '2005' 'Possibly 1995' '1997' '1989'
#  '2011' '2012' '1999 (Carlos Museum)' '1965' '1800s' '2002' '2010-2013'
#  '2001' '1955 (acquired by the VMFA from the PAM)' 'Various'
#  'since the 1960s' '2019' 'Between 1979-1988 (Getty Museum)' '1971'
#  '1974 (Indianapolis Museum of Art loan)'
#  '2013 (Houston Museum of Natural Sciences)' '2008 or before'
#  '2014 (not accessioned)' '1978' '2017' '1927' 'Wooden Hen: 1986'
#  '1926: Burial items\r\n1969: Human remains' '1939' '2024']
#
# Date Looted
# ['1980' 'Unknown' 'late 1970s' '2003' 'Before 1982' '1976 or 1977' '1976'
#  '1988' '1971' '1979-1980' 'circa November 1976' '1970s or early 1980s'
#  'April 1984' 'Likely between 1937 and 1945' 'April 1991' '1981'
#  'Before 2003' '1960' 'pre 1966' '2001' '1991 or earlier' '1990' '1970s'
#  'pre 1981' 'Late 1800s to early 1900s' 'before 1968' "1950's"
#  'circa 1989' '1982' 'c. 1972 (Khmer Rouge era)' '1956' '1899' 'July 1994'
#  'c. 1972 (Khmer Rouge era), if not earlier' 'Early 2006 or before' '1911'
#  "1970's" '1977 or 1978' 'Before 1976' 'For the mosaics, 1987 or earlier'
#  '2002 & 2003' 'Late 1980s to 1990s' '1998 or earlier' '2010 or after'
#  'late 1800s' '1936' '1959 or later' '1960s or later'
#  'mid-1960s or earlier' '2008' 'circa 1965' '2006' '1964' '1860' '1990s'
#  '1991' '1937' '1930s' '1970 or earlier'
#  'No later than the mid-1700s C.E.' '1928'
#  'Scientifically excavated in 1980' '1984' '1994' '2005 or before' '1897'
#  '1967' 'May 1967' '1960s' '1860s' '1874' '1882 - 1884'
#  'c. 2001 C.E. or before' 'Mostly 1975 or earlier' '2011 or earlier'
#  'September 1997' '2000' '1996 or earlier' '1962' 'Various'
#  '1999 or earlier' '1950s-1960s' '2007' '1979' 'various' 'after 1974'
#  '1974' '1975' 'circa 1967' '2008 or before'
#  'After 1957, when Ban Chiang was discovered' '2010 or earlier'
#  'Possibly 2004' 'after 1909' 'Early 1960s' '2011' 'circa 1975'
#  'approx. 1970s' '1966-1968' '9 March 1997' 'before 2005'
#  'Pre-1965. (First appearance of figure in advertisement is in 1965)'
#  '1765' '13th April 1868' '1952 - 1967' 'Between 1914 and 1938' '1943'
#  '1915: Burial items\r\n1948 - 1952: Human remains' '1944' 'circa 1987']

# %%
cols_num = "Year Returned","Year Acquired","Date Looted"
for col in cols_num:
    df_mola_final[col] = pd.to_numeric(df_mola_final[col], errors="coerce") #convert & clean
    print(f"\n{col}")
    print(df_mola_final[col].dropna().unique())
# Out:
# Year Returned
# [2006. 2012. 2010. 2008. 2005. 2007. 1999. 2011. 1996. 2014. 1952. 2000.
#  2013. 1988. 2020. 2016. 2015. 1992. 1976. 2001. 1991. 2004. 2022. 2021.
#  2023. 2002. 2018. 2017. 1982. 2009. 2003. 2024. 2019. 1993. 1986. 1998.
#  2025.]
#
# Year Acquired
# [1992. 1986. 1977. 1996. 1981. 1990. 1983. 1985. 1972. 1993. 1984. 1948.
#  1982. 1966. 1967. 1991. 1979. 2014. 1932. 2016. 1999. 2000. 1973. 2006.
#  1988. 1976. 1968. 2010. 2007. 2008. 1975. 1937. 1935. 1929. 1980. 2005.
#  1997. 1989. 2011. 2012. 1965. 2002. 2001. 2019. 1971. 1978. 2017. 1927.
#  1939. 2024.]
#
# Date Looted
# [1980. 2003. 1976. 1988. 1971. 1981. 1960. 2001. 1990. 1982. 1956. 1899.
#  1911. 1936. 2008. 2006. 1964. 1860. 1991. 1937. 1928. 1984. 1994. 1897.
#  1967. 1874. 2000. 1962. 2007. 1979. 1974. 1975. 2011. 1765. 1943. 1944.]

# %%
df_mola_final["Object Type"] = df_mola_final["Object Type"].str.split(" – ").str[0].str.strip()
print(df_mola_final["Object Type"].dropna().unique())
# Out:
# ['Sculpture' 'Vessel' 'Lighting Device' 'Various' 'Funerary Object'
#  'Currency' 'Jewelry' 'Religious Work' 'Architecture'
#  'Information Artifact' 'Visual Work' 'Monument' 'Tablet' 'Fragment'
#  'Architectural Element' 'Ornament' 'Obelisk' 'Textile' 'Human Remains'
#  'Equipment']

# %%
df_mola_final = df_mola_final[["id", "Object Type", "Object Materials", "Sending Country", "Receiving Country","Year Returned","Year Acquired","Date Looted"]]
df_mola_final.columns = df_mola_final.columns.str.strip().str.lower().str.replace(" ","_")
#df_mola_final.value_counts
#df_mola_final.dtypes

# %%
df_mola_final.to_csv("../data/raw/mola_artefacts.csv", sep = ';', index = False, encoding = "utf-8")
